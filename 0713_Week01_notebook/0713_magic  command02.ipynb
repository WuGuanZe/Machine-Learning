# %%
# %run  0713_test02.py
# Out:
# 11

# %%
# %load 0713_test02.py
x=5
y=6
z=x+y
print(z)

# %%
# %pwd
# Out:
# '/home/ds129'

# %%
foo=%pwd
foo
# Out:
# '/home/ds129'

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline
plot([-2,5,-3,6,-4])

# %%
plot(rand(10))

# %%
plot(randn(10))

# %%
plot(rand(100))

# %%
plot(randn(100))

# %% [markdown]
# $f(x)=x^2$

# %% [markdown]
# $$f(x)=x^2$$

# %% [markdown]
# $\int_a^b f(x) \,dx$

# %% [markdown]
# $$\int_a^b f(x) \,dx$$

# %% [markdown]
# ## 各鄉鎮市區人口密度資料集

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dsp = pd.read_csv("opendata106N0101.csv")

# %%
dsp.count()
# Out:
# 統計年      370
# 區域別      370
# 年底人口數    370
# 土地面積     368
# 人口密度     368
# dtype: int64

# %%
dsp
# Out:
#      統計年     區域別   年底人口數      土地面積     人口密度
# 0    106  新北市板橋區  551480   23.1373  23835.0
# 1    106  新北市三重區  387484   16.3170  23747.0
# 2    106  新北市中和區  413590   20.1440  20532.0
# 3    106  新北市永和區  222585    5.7138  38956.0
# 4    106  新北市新莊區  416524   19.7383  21102.0
# 5    106  新北市新店區  302089  120.2255   2513.0
# 6    106  新北市樹林區  184149   33.1288   5559.0
# 7    106  新北市鶯歌區   86593   21.1248   4099.0
# 8    106  新北市三峽區  114926  191.4508    600.0
# 9    106  新北市淡水區  169597   70.6565   2400.0
# 10   106  新北市汐止區  199321   71.2354   2798.0
# 11   106  新北市瑞芳區   40353   70.7336    570.0
# 12   106  新北市土城區  238067   29.5578   8054.0
# 13   106  新北市蘆洲區  201309    7.4351  27075.0
# 14   106  新北市五股區   84919   34.8632   2436.0
# 15   106  新北市泰山區   78911   19.1603   4118.0
# 16   106  新北市林口區  106101   54.1519   1959.0
# 17   106  新北市深坑區   23660   20.5787   1150.0
# 18   106  新北市石碇區    7683  144.3498     53.0
# 19   106  新北市坪林區    6528  170.8350     38.0
# ...

# %%
dsp.head()
# Out:
#    統計年     區域別   年底人口數     土地面積     人口密度
# 0  106  新北市板橋區  551480  23.1373  23835.0
# 1  106  新北市三重區  387484  16.3170  23747.0
# 2  106  新北市中和區  413590  20.1440  20532.0
# 3  106  新北市永和區  222585   5.7138  38956.0
# 4  106  新北市新莊區  416524  19.7383  21102.0

# %%
dsp.tail()
# Out:
#      統計年     區域別  年底人口數  土地面積   人口密度
# 365  106  連江縣北竿鄉   2360   9.9  238.0
# 366  106  連江縣莒光鄉   1624   4.7  346.0
# 367  106  連江縣東引鄉   1352   3.8  356.0
# 368  106    東沙群島      0   NaN    NaN
# 369  106    南沙群島      0   NaN    NaN

# %%
dsp.年底人口數.mean()
# Out:
# 63706.01891891892

# %%
dsp.index = range(1, 371)

# %%
dsp[["年底人口數", "人口密度"]]
# Out:
#       年底人口數     人口密度
# 1    551480  23835.0
# 2    387484  23747.0
# 3    413590  20532.0
# 4    222585  38956.0
# 5    416524  21102.0
# 6    302089   2513.0
# 7    184149   5559.0
# 8     86593   4099.0
# 9    114926    600.0
# 10   169597   2400.0
# 11   199321   2798.0
# 12    40353    570.0
# 13   238067   8054.0
# 14   201309  27075.0
# 15    84919   2436.0
# 16    78911   4118.0
# 17   106101   1959.0
# 18    23660   1150.0
# 19     7683     53.0
# 20     6528     38.0
# 21    23200    352.0
# 22    12286    240.0
# 23    38493    975.0
# 24     4719     66.0
# 25     8939     61.0
# 26    12552    126.0
# 27    22015    447.0
# 28    22296    352.0
# 29     6320     20.0
# 30   206988  22286.0
# ..      ...      ...
# 341   62308   1833.0
# 342   14508    436.0
# 343    9817    489.0
# 344    8408    449.0
# 345    5176    376.0
# 346    3856    552.0
# 347   52163   5108.0
# 348   53972    959.0
# 349   38708   1696.0
# 350   44314  10467.0
# 351   47908   4552.0
# ...

# %%
dsp.人口密度.plot()

# %%
dsp.人口密度.hist(bins = 15)

# %%
dsp.describe()
# Out:
#          統計年          年底人口數         土地面積          人口密度
# count  370.0     370.000000   368.000000    368.000000
# mean   106.0   63706.018919    98.353757   2768.970109
# std      0.0   82886.532344   180.181365   5589.809439
# min    106.0       0.000000     0.880300      5.000000
# 25%    106.0   14516.000000    29.866000    225.750000
# 50%    106.0   30684.000000    53.577300    634.000000
# 75%    106.0   77806.000000    89.811550   1940.250000
# max    106.0  551480.000000  1641.855500  38956.000000
